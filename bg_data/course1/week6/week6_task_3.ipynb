# %% [markdown]
# Calculate tf*idf for each pair (word, article) from the Wikipedia dump. Apply the stop words filter to speed up calculations. Term frequency (tf) is a function depending on a term (word) and a document (article):
#
# tf(term, doc_id) = Nt/N,
#
# where Nt - quantity of particular term in the document, N - the total number of terms in the document (without stop words)
#
# Inverse document frequency (idf) is a function depends on a term:
#
# idf(term) = 1/log(1 + Dt),
#
# where Dt - number of documents in the dataset with the particular term.
#
# You can find more information here: https://en.wikipedia.xn--org/wiki/Tfidf-q82h but use just the formulas mentioned above.
#
# Output: tf*idf for term=’labor’ and article_id=12

# %%
# %%writefile mapper.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode


def read_vocabulary(file_path):
    with open(file_path, 'r') as infile:
        return set(infile.read().splitlines())

stop_words = read_vocabulary("stop_words.txt")


for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue

    text = re.sub("^\W+|\W+$", "", text, flags=re.UNICODE)
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)

    for word in words:
        if word.lower() in stop_words:
            continue
        print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % 1
        print '{article_id}\t{word}\t{count}'.format(article_id=article_id, word=word.lower(), count=1)
        print '0\t{article_id}\t{count}'.format(article_id=article_id, count=1)
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py

import sys

current_key = None
word_sum = 0

for line in sys.stdin:
    try:
        article_id, word, count = line.strip().split('\t', 2)
        key = article_id, word
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            print '{key[0]}\t{key[1]}\t{count}'.format(key=current_key, count=word_sum)
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    print '{key[0]}\t{key[1]}\t{count}'.format(key=current_key, count=word_sum)
# Out:
# Overwriting reducer.py

# %%
# %%writefile reducer_idf.py

import sys
import os
from math import log

current_key = None
word_sum = 0
total = float(os.environ.get('TOTAL_ARTICLES'))

for line in sys.stdin:
    try:
        word, _ = line.strip().split('\t', 1)
        key = word
    except ValueError as e:
        continue
    print 'tf\t{}'.format(line.strip())
    if current_key != key:
        if current_key:
            print 'idf\t{key}\t{count:.12f}'.format(key=current_key, count=log(total / word_sum))
        word_sum = 0
        current_key = key
    word_sum += 1

if current_key:
    print 'idf\t{key}\t{count:.12f}'.format(key=current_key, count=log(total / word_sum))
# Out:
# Overwriting reducer_idf.py

# %%
# %%writefile mapper_tf.py

import sys
import os
import re
import subprocess

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

articles = {}
with open ('articles.txt', 'r') as infile:
    for row in infile:
        key, value = row.strip().split()
        articles[key] = float(value)

for line in sys.stdin:
    try:
        article_id, word, count = line.strip().split('\t', 2)
        count = int(count)
    except ValueError as e:
        continue
    if article_id == '0':
        continue
    print '{word}\t{article_id}\t{count:.12f}'.format(
        article_id=article_id, word=word, count=count / articles[article_id])
# Out:
# Overwriting mapper_tf.py

# %%
# %%bash
#
# NUM_REDUCERS=8
#
# IN_DIR="/data/wiki/en_articles_part"
# COUNT_DIR="tf_idf_count" # $(date +"%s%6N")
# ARTICLES='articles_count.txt' # $(date +"%s%6N")
# TF_IDF_DIR="tf_idf_out" # $(date +"%s%6N")
#
# hdfs dfs -rm -r -f -skipTrash ${COUNT_DIR} > /dev/null
# hdfs dfs -rm -r -f -skipTrash ${TF_IDF_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.name="Prepare word counts" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -D stream.num.map.output.key.fields=2 \
#     -files mapper.py,reducer.py,/datasets/stop_words_en.txt#stop_words.txt \
#     -mapper "python mapper.py" \
#     -combiner "python reducer.py" \
#     -reducer "python reducer.py" \
#     -input ${IN_DIR} \
#     -output ${COUNT_DIR} > /dev/null
#
# # calc idf * tf for each word
# hdfs dfs -text ${COUNT_DIR}/part* | egrep "^0\s" | cut -d$'\t' -f2,3 > ${ARTICLES}
# total_articles=`wc -l ${ARTICLES} | cut -d' ' -f1`
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.name="Calc tf idf" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper_tf.py,reducer_idf.py,${ARTICLES}#articles.txt \
#     -cmdenv TOTAL_ARTICLES=$total_articles \
#     -mapper "python mapper_tf.py" \
#     -reducer "python reducer_idf.py" \
#     -input ${COUNT_DIR} \
#     -output ${TF_IDF_DIR} > /dev/null
#
# # print answ
# echo `hdfs dfs -text ${TF_IDF_DIR}/part* | grep '^tf\slabor\s12\s'` \
#     `hdfs dfs -text ${TF_IDF_DIR}/part* | egrep '^idf\slabor\s'` \
#     | awk '{printf ("%f", $4 * $7) }'
# Out:
# 0.005326
# 17/10/30 15:01:43 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/10/30 15:01:43 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/10/30 15:01:43 INFO mapred.FileInputFormat: Total input files to process : 1
# 17/10/30 15:01:43 INFO mapreduce.JobSubmitter: number of splits:2
# 17/10/30 15:01:43 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1509357171066_0043
# 17/10/30 15:01:44 INFO impl.YarnClientImpl: Submitted application application_1509357171066_0043
# 17/10/30 15:01:44 INFO mapreduce.Job: The url to track the job: http://7e19e138f0cc:8088/proxy/application_1509357171066_0043/
# 17/10/30 15:01:44 INFO mapreduce.Job: Running job: job_1509357171066_0043
# 17/10/30 15:01:50 INFO mapreduce.Job: Job job_1509357171066_0043 running in uber mode : false
# 17/10/30 15:01:50 INFO mapreduce.Job:  map 0% reduce 0%
# 17/10/30 15:02:08 INFO mapreduce.Job:  map 21% reduce 0%
# 17/10/30 15:02:14 INFO mapreduce.Job:  map 31% reduce 0%
# 17/10/30 15:02:20 INFO mapreduce.Job:  map 36% reduce 0%
# 17/10/30 15:02:26 INFO mapreduce.Job:  map 38% reduce 0%
# 17/10/30 15:02:32 INFO mapreduce.Job:  map 49% reduce 0%
# 17/10/30 15:02:38 INFO mapreduce.Job:  map 59% reduce 0%
# 17/10/30 15:02:44 INFO mapreduce.Job:  map 64% reduce 0%
# 17/10/30 15:02:56 INFO mapreduce.Job:  map 72% reduce 0%
# 17/10/30 15:03:00 INFO mapreduce.Job:  map 86% reduce 0%
# 17/10/30 15:03:01 INFO mapreduce.Job:  map 100% reduce 0%
# 17/10/30 15:03:18 INFO mapreduce.Job:  map 100% reduce 13%
# 17/10/30 15:03:22 INFO mapreduce.Job:  map 100% reduce 25%
# 17/10/30 15:03:24 INFO mapreduce.Job:  map 100% reduce 38%
# 17/10/30 15:03:25 INFO mapreduce.Job:  map 100% reduce 50%
# 17/10/30 15:03:27 INFO mapreduce.Job:  map 100% reduce 63%
# 17/10/30 15:03:28 INFO mapreduce.Job:  map 100% reduce 75%
# 17/10/30 15:03:32 INFO mapreduce.Job:  map 100% reduce 88%
# 17/10/30 15:03:33 INFO mapreduce.Job:  map 100% reduce 100%
# 17/10/30 15:03:33 INFO mapreduce.Job: Job job_1509357171066_0043 completed successfully
# 17/10/30 15:03:33 INFO mapreduce.Job: Counters: 51
# 	File System Counters
# 		FILE: Number of bytes read=119139934
# 		FILE: Number of bytes written=179969448
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=52568596
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=9
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=137267
# 		Total time spent by all reduces in occupied slots (ms)=130594
# 		Total time spent by all map tasks (ms)=137267
# 		Total time spent by all reduce tasks (ms)=130594
# 		Total vcore-milliseconds taken by all map tasks=137267
# 		Total vcore-milliseconds taken by all reduce tasks=130594
# 		Total megabyte-milliseconds taken by all map tasks=140561408
# 		Total megabyte-milliseconds taken by all reduce tasks=133728256
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=13942052
# 		Map output bytes=164794123
# 		Map output materialized bytes=59522163
# 		Input split bytes=228
# 		Combine input records=17418779
# 		Combine output records=6953451
# 		Reduce input groups=32720
# 		Reduce shuffle bytes=59522163
# 		Reduce input records=3476724
# 		Reduce output records=3476724
# 		Spilled Records=10430175
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=2334
# 		CPU time spent (ms)=195470
# 		Physical memory (bytes) snapshot=2035154944
# 		Virtual memory (bytes) snapshot=19673620480
# 		Total committed heap usage (bytes)=1573388288
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	Wiki stats
# 		Total words=6971026
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=52568596
# 17/10/30 15:03:33 INFO streaming.StreamJob: Output directory: tf_idf_count
# 17/10/30 15:03:37 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/10/30 15:03:37 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/10/30 15:03:38 INFO mapred.FileInputFormat: Total input files to process : 8
# 17/10/30 15:03:39 INFO mapreduce.JobSubmitter: number of splits:8
# 17/10/30 15:03:39 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1509357171066_0044
# 17/10/30 15:03:39 INFO impl.YarnClientImpl: Submitted application application_1509357171066_0044
# 17/10/30 15:03:39 INFO mapreduce.Job: The url to track the job: http://7e19e138f0cc:8088/proxy/application_1509357171066_0044/
# 17/10/30 15:03:39 INFO mapreduce.Job: Running job: job_1509357171066_0044
# 17/10/30 15:03:46 INFO mapreduce.Job: Job job_1509357171066_0044 running in uber mode : false
# 17/10/30 15:03:46 INFO mapreduce.Job:  map 0% reduce 0%
# 17/10/30 15:04:06 INFO mapreduce.Job:  map 38% reduce 0%
# 17/10/30 15:04:07 INFO mapreduce.Job:  map 75% reduce 0%
# 17/10/30 15:04:25 INFO mapreduce.Job:  map 100% reduce 0%
# 17/10/30 15:04:31 INFO mapreduce.Job:  map 100% reduce 9%
# 17/10/30 15:04:33 INFO mapreduce.Job:  map 100% reduce 22%
# 17/10/30 15:04:34 INFO mapreduce.Job:  map 100% reduce 47%
# 17/10/30 15:04:35 INFO mapreduce.Job:  map 100% reduce 50%
# 17/10/30 15:04:43 INFO mapreduce.Job:  map 100% reduce 75%
# 17/10/30 15:04:46 INFO mapreduce.Job:  map 100% reduce 100%
# 17/10/30 15:04:46 INFO mapreduce.Job: Job job_1509357171066_0044 completed successfully
# 17/10/30 15:04:46 INFO mapreduce.Job: Counters: 51
# 	File System Counters
# 		FILE: Number of bytes read=104540508
# 		FILE: Number of bytes written=211320320
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=52569468
# 		HDFS: Number of bytes written=120562751
# 		HDFS: Number of read operations=48
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed map tasks=1
# 		Killed reduce tasks=1
# 		Launched map tasks=8
# 		Launched reduce tasks=9
# 		Data-local map tasks=8
# 		Total time spent by all maps in occupied slots (ms)=146125
# 		Total time spent by all reduces in occupied slots (ms)=156844
# 		Total time spent by all map tasks (ms)=146125
# 		Total time spent by all reduce tasks (ms)=156844
# 		Total vcore-milliseconds taken by all map tasks=146125
# 		Total vcore-milliseconds taken by all reduce tasks=156844
# 		Total megabyte-milliseconds taken by all map tasks=149632000
# 		Total megabyte-milliseconds taken by all reduce tasks=160608256
# 	Map-Reduce Framework
# 		Map input records=3476724
# 		Map output records=3472623
# 		Map output bytes=97595204
# 		Map output materialized bytes=104540844
# 		Input split bytes=872
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=426241
# 		Reduce shuffle bytes=104540844
# 		Reduce input records=3472623
# 		Reduce output records=3898864
# 		Spilled Records=6945246
# 		Shuffled Maps =64
# 		Failed Shuffles=0
# 		Merged Map outputs=64
# 		GC time elapsed (ms)=3321
# 		CPU time spent (ms)=62290
# 		Physical memory (bytes) snapshot=3732811776
# 		Virtual memory (bytes) snapshot=31439671296
# 		Total committed heap usage (bytes)=2737831936
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=52568596
# 	File Output Format Counters
# 		Bytes Written=120562751
# 17/10/30 15:04:46 INFO streaming.StreamJob: Output directory: tf_idf_out
